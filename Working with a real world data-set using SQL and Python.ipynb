# %%
import sys,os,os.path
os.environ['IBM_DB_HOME']='C:\Program Files\IBM\SQLLIB'
# !pip –upgrade ipython-sql
# !pip –upgrade ibm_db 
# !pip –upgrade ibm_db_sa
# Out:
# ERROR: unknown command "–upgrade"
#
# ERROR: unknown command "–upgrade"
#
# ERROR: unknown command "–upgrade"

# %%
import ibm_db
import ibm_db_sa
import sqlalchemy
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# %sql ibm_db_sa://mpj68093:9yAbZHBew2CdyBfv@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb?ssl=true
# Out:
# (ibm_db_dbi.OperationalError) ibm_db_dbi::OperationalError: [IBM][CLI Driver] SQL30081N  A communication error has been detected. Communication protocol being used: "TCP/IP".  Communication API being used: "SOCKETS".  Location where the error was detected: "158.175.131.250".  Communication function detecting the error: "recv".  Protocol specific error code(s): "10054", "*", "0".  SQLSTATE=08001\r SQLCODE=-30081
# (Background on this error at: http://sqlalche.me/e/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES \
      where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# (ibm_db_dbi.OperationalError) ibm_db_dbi::OperationalError: [IBM][CLI Driver] SQL30082N  Security processing failed with reason "19" ("USERID DISABLED or RESTRICTED").  SQLSTATE=08001\r SQLCODE=-30082
# [SQL: select TABSCHEMA, TABNAME, CREATE_TIME from SYSCAT.TABLES where TABSCHEMA not in ('SYSIBM', 'SYSCAT', 'SYSSTAT', 'SYSIBMADM', 'SYSTOOLS', 'SYSPUBLIC')]
# ...

# %%
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# Done.
# [('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('HARDSHIP_INDEX', 'SMALLINT', 2),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'DECIMAL ', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'DECIMAL ', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'DECIMAL ', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'DECIMAL ', 4),
#  ('PERCENT_OF_HOUSING_CROWDED', 'DECIMAL ', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER ', 4)]

# %%
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'CHICAGO_PUBLIC_SCHOOLS'
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# Done.
# [('10th Grade PLAN (2009)', 'VARCHAR ', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 4),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 4),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 6),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 6),
#  ('CITY', 'VARCHAR ', 7),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 34),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 4),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 4),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 15),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 16),
#  ('ENVIRONMENT_ICON', 'VARCHAR ', 11),
# ...

# %%
# %sql select distinct(NAME), COLTYPE, LENGTH from SYSIBM.SYSCOLUMNS where TBNAME = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# Done.
# [('ARREST', 'VARCHAR ', 5),
#  ('BEAT', 'SMALLINT', 2),
#  ('BLOCK', 'VARCHAR ', 35),
#  ('CASE_NUMBER', 'VARCHAR ', 8),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('DATE', 'DATE    ', 4),
#  ('DESCRIPTION', 'VARCHAR ', 46),
#  ('DISTRICT', 'SMALLINT', 2),
#  ('DOMESTIC', 'VARCHAR ', 5),
#  ('FBICODE', 'VARCHAR ', 3),
#  ('ID', 'INTEGER ', 4),
#  ('IUCR', 'VARCHAR ', 4),
#  ('LATITUDE', 'DECIMAL ', 18),
#  ('LOCATION', 'VARCHAR ', 29),
#  ('LOCATION_DESCRIPTION', 'VARCHAR ', 33),
#  ('LONGITUDE', 'DECIMAL ', 18),
#  ('PRIMARY_TYPE', 'VARCHAR ', 15),
#  ('WARD', 'SMALLINT', 2),
#  ('X_COORDINATE', 'INTEGER ', 4),
#  ('YEAR', 'SMALLINT', 2),
#  ('Y_COORDINATE', 'INTEGER ', 4)]

# %%
# %sql select DISTINCT(A.PRIMARY_TYPE) from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# (ibm_db_dbi.OperationalError) ibm_db_dbi::OperationalError: [IBM][CLI Driver] SQL30082N  Security processing failed with reason "19" ("USERID DISABLED or RESTRICTED").  SQLSTATE=08001\r SQLCODE=-30082
# [SQL: select DISTINCT(A.PRIMARY_TYPE) from CHICAGO_CRIME_DATA]
# ...

# %%
# %sql select DISTINCT(A.PRIMARY_TYPE) from CHICAGO_CRIME_DATA where LOCATION_DESCRIPTION like "%SCHOOL"
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# Done.
# [(34,)]

# %%
# %sql select count(CASE_NUMBER) from CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# Done.
# [(533,)]

# %%
# %sql select COMMUNITY_AREA_NAME, PER_CAPITA_INCOME from CENSUS_DATA where PER_CAPITA_INCOME > 11000
# Out:
#  * ibm_db_sa://mpj68093:***@3883e7e4-18f5-4afe-be8c-fa31c41761d2.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31498/bludb
# Done.
# [('Rogers Park', 23939),
#  ('West Ridge', 23040),
#  ('Uptown', 35787),
#  ('Lincoln Square', 37524),
#  ('North Center', 57123),
#  ('Lake View', 60058),
#  ('Lincoln Park', 71551),
#  ('Near North Side', 88669),
#  ('Edison Park', 40959),
#  ('Norwood Park', 32875),
#  ('Jefferson Park', 27751),
#  ('Forest Glen', 44164),
#  ('North Park', 26576),
#  ('Albany Park', 21323),
#  ('Portage Park', 24336),
#  ('Irving Park', 27249),
#  ('Dunning', 26282),
#  ('Montclaire', 22014),
#  ('Belmont Cragin', 15461),
#  ('Hermosa', 15089),
#  ('Avondale', 20039),
#  ('Logan Square', 31908),
#  ('Humboldt park', 13781),
#  ('West Town', 43198),
#  ('Austin', 15957),
#  ('East Garfield Park', 12961),
#  ('Near West Side', 44689),
#  ('North Lawndale', 12034),
#  ('Lower West Side', 16444),
#  ('Loop', 65526),
#  ('Near South Side', 59077),
# ...
